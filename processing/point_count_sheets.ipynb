# %%
# == Global Libraries == #
import json
import numpy as np
import os
import pandas as pd
import sys

# == Locate Root Dir == #
flare = '\\flare.py'
path = os.getcwd()
while not os.path.isfile(path + flare):
    path = os.path.dirname(path)
sys.path.append(path)

# == Local Modules == #
from functions.general import change_dtype, load_json

# %% [markdown]
# # Import Data

# %%
# == Load and Store Reference Data == #
path = 'C:/Users/Work/Documents/Repos/avian_monitoring/data/cleaned/species_codes.json'
species_dict = load_json(path)

observer_ids = ['CKD']
site_ids = ['CC', 'CT', 'RW', 'JW', 'DQ']
species_codes = list(
    pd.DataFrame \
    .from_dict(species_dict, orient='index') \
    .reset_index()['index'] \
    .unique()
)
how_codes = ['V', 'S', 'C', 'O']
bool_codes = ['X']
sex_codes = ['M', 'F', 'J']

# %%
def load_point_counts_csv(path):
    names = ['observer_id', 'year', 'month', 'day', 'site_id', 'start_time', 'point', 'minute', 'species_code',
             'distance', 'how', 'visual', 'sex', 'migrating', 'cluster_size', 'cluster_code', 'notes']
    dtypes = {'observer_id': 'string', 'year': 'int64', 'month': 'int64', 'day': 'int64', 'site_id': 'string', 
              'start_time': 'string', 'point': 'int64', 'minute': 'object', 'species_code': 'string',
              'distance': 'object', 'how': 'string', 'visual': 'string', 'sex': 'string', 'migrating': 'string', 
              'cluster_size': 'object', 'cluster_code': 'string', 'notes': 'string'}
    return pd.read_csv(path, header=1, names=names, dtype=dtypes)

def uppercase(df, cols): 
    df[cols] = df[cols].apply(lambda x: x.str.upper())
    return df

def check_categories(df, col, categories):
    df = df[~df[col].isin(categories)]
    df = df.dropna(subset=[col])
    if len(df) > 0:
        print(df[col])
        raise ValueError(f"Records in column '{col}' to do not belong to a defined category.")

# %%
# == Load and Process Point Count Sheets == #
path = r'C:/Users/Work/Documents/Repos/avian_monitoring/data/raw/point_counts_2020-06-21.csv'
df1 = load_point_counts_csv(path)

path = r'C:/Users/Work/Documents/Repos/avian_monitoring/data/raw/point_counts_2021-07-02.csv'
df2 = load_point_counts_csv(path)

# %%
# make "observer_id", "site_id", "species_code", "how", "visual", "sex", "migrating", "cluster_code" all caps
upper_cols = ['observer_id', 'site_id', 'species_code', 'how', 'visual', 'sex', 'migrating', 'cluster_code']
df1 = uppercase(df1, upper_cols)

# check category matches for "observer_id", "site_id", "species_code", "how", "visual", "sex", "migrating"
categorical_cols = ['observer_id', 'site_id', 'species_code', 'how', 'visual', 'sex', 'migrating']
categories = [observer_ids, site_ids, species_codes, how_codes, bool_codes, sex_codes, bool_codes]
for i in range(len(categorical_cols)):
    check_categories(df1, categorical_cols[i], categories[i])

# convert "year", "month", and "day" to single datetime column
# convert visual and migrating to T/F

# %% [markdown]
# # Import Data

# %%
#### FUNCTIONS ####

def valueCount(column):
    x = column.value_counts()
    return x

def fillDown(data, column, row):
    if pd.isna(data[column][row]) and data['Point'][row] != '88':
        data.at[row, column]=data.at[row-1, column]
    else:
        pass

# %%
birds.dtypes
# ObserverID      object
# Year           float64
# Month          float64
# Day            float64
# SurveyID        object
# Start Time      object
# Point           object
# Minute         float64
# SpeciesCode     object
# Distance        object
# How             object
# Visual          object
# Sex             object
# Migrating       object
# ClusterSize     object
# ClusterCode     object
# Notes          float64

# Dtypes Handled 6/21/2020:
# should be float/int (Distance, ClusterSize)

for header in list(birds.columns):
    print(valueCount(birds[header]))
# Exceptions Handled 6/21/2020:
# change 'D & Q' to 'DQ' (SurveyID)
# fix '0:00' and '5^' (Point)
# fix '88.0' (Minute)
# fix 'C ' (Distance)
# fix 'C' (How)
# fix 'M', 'F', and 'J' (Visual)
# investigate inputs (Migrating)
# investigate inputs (ClusterSize)
# change dtype (ClusterSize)

birds.isna().sum().sort_values(ascending=False)
# NA's Handled 6/21/2020:
# make Y/N (Migrating, Visual)
# delete empty lines
# fill in known nans ()
# Out:
# CKD    1518
# Name: ObserverID, dtype: int64
# 2020.0    1518
# Name: Year, dtype: int64
# 6.0    887
# 5.0    631
# Name: Month, dtype: int64
# 3.0     304
# 2.0     292
# 1.0     291
# 29.0    268
# 27.0    209
# 28.0    154
# Name: Day, dtype: int64
# CC       596
# CT       291
# RW       268
# JW       209
# D & Q    154
# Name: SurveyID, dtype: int64
# 5:40    33
# 6:07    30
# 5:54    28
# 6:06    27
# 8:28    25
# 8:37    25
# 7:14    24
# 8:08    23
# 6:20    23
# 6:37    23
# 7:00    22
# 6:47    20
# 6:22    20
# 6:32    19
# 7:28    17
# 7:31     2
# 7:30     1
# 6:24     1
# 6:09     1
# 7:05     1
# 7:55     1
# 6:21     1
# 5:48     1
# 6:51     1
# 6:33     1
# 8:07     1
# 8:00     1
# 6:01     1
# 6:26     1
# 7:29     1
# 7:20     1
# 7:45     1
# 6:12     1
# 8:11     1
# 5:52     1
# 6:44     1
# 5:56     1
# 8:23     1
# 8:09     1
# 5:28     1
# 6:57     1
# 6:11     1
# 7:19     1
# 6:54     1
# 7:18     1
# 7:46     1
# 5:41     1
# 7:06     1
# 7:40     1
# 7:08     1
# 7:43     1
# 6:30     1
# 6:41     1
# Name: Start Time, dtype: int64
# 5       155
# 1       143
# 6       130
# 4       130
# 2       130
# 3       124
# 9        98
# 7        92
# 8        91
# 20       55
# 10       43
# 11       39
# 19       36
# 17       33
# 22       29
# 21       25
# 16       24
# 23       22
# 15       22
# 13       21
# 18       21
# 12       18
# 14       15
# 88       13
# 5^        1
# 0:00      1
# Name: Point, dtype: int64
# 1.0     581
# 2.0     254
# 3.0     226
# 4.0     171
# 5.0     138
# 6.0     128
# 88.0      1
# Name: Minute, dtype: int64
# DICK    292
# RWBL    261
# BHCO     84
# EAME     74
# COGR     63
#        ...
# WBNU      1
# EAPH      1
# ALFL      1
# YBFL      1
# DOWO      1
# Name: SpeciesCode, Length: 85, dtype: int64
# 100     346
# 150     175
# 125     139
# 75       85
# 50       84
# 80       70
# 200      65
# 120      56
# 300      52
# 130      44
# 250      38
# 60       38
# 90       35
# 175      31
# 140      30
# 110      29
# 30       21
# 70       20
# 40       20
# 170      18
# 400      15
# 225      10
# 350       9
# 180       8
# 275       5
# 500       5
# 160       4
# 45        4
# 20        4
# 95        3
# 700       3
# 220       3
# 999       2
# 25        2
# 65        2
# 800       2
# 1000      1
# 600       1
# 230       1
# 260       1
# 280       1
# 550       1
# C         1
# 190       1
# 55        1
# 85        1
# 35        1
# 115       1
# 240       1
# 10        1
# 210       1
# 450       1
# Name: Distance, dtype: int64
# V     704
# S     452
# C     345
# C       1
# Name: How, dtype: int64
# X    701
# M     10
# F      4
# J      1
# Name: Visual, dtype: int64
# M    252
# F     69
# Name: Sex, dtype: int64
# 2     10
# 4      4
# 3      3
# X      3
# 5      2
# 40     1
# 1      1
# 20     1
# 6      1
# Name: Migrating, dtype: int64
# 2     104
# 3      53
# 4      17
# 1      15
# 6       4
# C       4
# 5       4
# F       2
# H       2
# G       2
# 25      1
# 10      1
# 12      1
# 28      1
# 8       1
# 43      1
# 20      1
# 26      1
# Name: ClusterSize, dtype: int64
# A    12
# D    10
# B    10
# F     6
# C     6
# E     4
# J     2
# I     2
# Name: ClusterCode, dtype: int64
# Series([], Name: Notes, dtype: int64)
# Notes          1520
# Migrating      1494
# ClusterCode    1468
# ClusterSize    1305
# Sex            1199
# Start Time     1122
# Visual          804
# Distance         27
# Minute           21
# How              18
# Point             9
# SpeciesCode       8
# SurveyID          2
# Day               2
# Month             2
# Year              2
# ObserverID        2
# dtype: int64

# %%
#### CLEAN ####

# make 'Start Time' 'StartTime'
birds.rename(columns={'Start Time':'StartTime'}, inplace=True)

# change 'D & Q' to 'DQ' (SurveyID)
birds['SurveyID'].replace('D & Q', 'DQ', inplace=True)

# fix '0:00' and '5^' (Point)
birds.loc[birds['Point']=='0:00'] # 743
birds.at[743, 'Point']='5'
birds.loc[birds['Point']=='5^'] # 744
birds.at[744, 'Point']='5'

# fix '88.0' (Minute)
birds.loc[birds['Minute']==88] # 271
birds.at[271, 'Minute']=float('NaN')
birds.at[271, 'Point']="88"

# fix 'C ' (Distance)
birds.loc[birds['Distance']=='C '] # 522
birds.at[522, 'Distance']=float('NaN')
birds.at[522, 'How']='C'

# fix 'C' (How)
birds.loc[birds['How']=='C '] # 812
birds.at[812, 'How']='C'

# fix 'M', 'F', and 'J' (Visual)
birds.loc[birds['Visual']=='M'] # multiple
birds.loc[birds['Visual']=='F'] # multiple
birds.loc[birds['Visual']=='J'] # 768
for letter in ['M', 'F', 'J']:
    rows = birds.loc[birds['Visual']==letter].index.to_numpy()
    for index in rows:
        birds.at[index, 'Visual']=1
        birds.at[index, 'Sex']=letter

# investigate inputs (Migrating)
for number in ['2', '4', '3', '5', '20', '40', '1', '6']:
    rows = birds.loc[birds['Migrating']==number].index.to_numpy()
    for index in rows:
        birds.at[index, 'Migrating']=0
        birds.at[index, 'ClusterCode']=birds.at[index, 'ClusterSize']
        birds.at[index, 'ClusterSize']=number

# investigate inputs (ClusterSize)
birds.loc[birds['ClusterSize']=='G'] # multiple
birds.loc[birds['ClusterSize']=='H'] # multiple
for letter in ['G', 'H']:
    rows = birds.loc[birds['ClusterSize']==letter].index.to_numpy()
    for index in rows:
        birds.at[index, 'ClusterSize']=1
        birds.at[index, 'ClusterCode']=letter

# change dtype (ClusterSize, Distance)
birds['ClusterSize'] = birds['ClusterSize'].astype('float64')
birds['Distance'] = birds['Distance'].astype('float64')

# make Y/N (Migrating, Visual)
birds = birds.fillna(value={'Migrating':0, 'Visual':0, 'ClusterSize':1, 'Sex':'U'})
birds['Visual'].replace('X', 1, inplace=True)
birds['Migrating'].replace('X', 1, inplace=True)

# delete empty lines
birds = birds.dropna(subset=['SpeciesCode'])
birds = birds.reset_index(drop=True) 

# fill in known nans (How, Minute, Distance, StartTime)
np.where(birds['How'].isnull())[0] # 600, 624, 676, 704, 777, 778, 1029, 1241, 1289
for number in [600, 624, 676, 704, 777, 778, 1029, 1241, 1289]:
    birds.at[number, 'How']='S'
np.where(birds['Minute'].isnull())[0] # 88s
np.where(birds['Distance'].isnull())[0] # 600, 624, 676, 1029, 1241, 1289
for number in [600, 624, 676, 1029, 1241, 1289]:
    birds.at[number, 'Distance']=round(birds['Distance'].mean(), 0)
for row in range(len(birds)):
    fillDown(birds, 'StartTime', row)

# fill in 88s
birds = birds.fillna(value={'StartTime':'00:00', 'Minute':88, 'Distance':round(birds['Distance'].mean(), 0)})

# %%
#### RE-CATEGORIZE AND QUALITY CHECK ####

# observedID
birds['ObserverID'].replace('CKD', 'Colin Kenneth Dobson', inplace=True)

# surveyID
birds['SurveyID'].replace('JW', 'J&W', inplace=True)
birds['SurveyID'].replace('DQ', 'DQ-80', inplace=True)
birds['SurveyID'].replace('RW', 'R Wildlife Farm and Fields LLC', inplace=True)
birds['SurveyID'].replace('CT', 'Craver Trust', inplace=True)
birds['SurveyID'].replace('CC', 'Cow Creek Farm', inplace=True)

# how
birds['How'].replace('V', 'Visual', inplace=True)
birds['How'].replace('C', 'Call', inplace=True)
birds['How'].replace('S', 'Song', inplace=True)

# sex
birds['Sex'].replace('M', 'Male', inplace=True)
birds['Sex'].replace('F', 'Female', inplace=True)
birds['Sex'].replace('J', 'Juvenile', inplace=True)
birds['Sex'].replace('U', 'Unknown', inplace=True)

# speciescode
# birds['SpeciesCode'].replace({'CLIS':'CLSW', 'CHIP':'CHSP', 'TRSW':'TRES', 'CAWR':'CARW', 'MAGW':'MAWA', 
#                               'AMRC':'AMCR', 'AMR':'AMRO'}, inplace=True)
birds['Species'] = birds['SpeciesCode'].map(species_dict)
birds = birds.fillna(value={'Species':'Error'})
birds['SpeciesName'] = birds['Species'].apply(lambda x: x[0] if len(x)==2 else 'Error')
birds['SpeciesGroup'] = birds['Species'].apply(lambda x: x[1] if len(x)==2 else 'Error')
for row in range(len(birds)):
    x = birds['Species'][row]
    if x[1] == 'None':
        birds.at[row, 'Species']=x[0]
    elif x == 'Error':
        pass
    else:
        birds.at[row, 'Species']=' '.join(x)

# rearrange categories
birds = birds[['ObserverID', 'Year', 'Month', 'Day', 'SurveyID', 'StartTime', 'Point',
               'Minute', 'SpeciesCode', 'Species', 'Distance', 'How', 'Visual', 'Sex',
               'Migrating', 'ClusterSize', 'ClusterCode', 'Notes', 'SpeciesName', 'SpeciesGroup']]

for header in list(birds.columns):
    print(valueCount(birds[header]))
# Errors Handled 6/22/2020:
# fix 'Error' (Species)
# fix 'None' (SpeciesGroup)
# Out:
# Colin Kenneth Dobson    1512
# Name: ObserverID, dtype: int64
# 2020.0    1512
# Name: Year, dtype: int64
# 6.0    887
# 5.0    625
# Name: Month, dtype: int64
# 3.0     304
# 2.0     292
# 1.0     291
# 29.0    266
# 27.0    207
# 28.0    152
# Name: Day, dtype: int64
# Cow Creek Farm                    596
# Craver Trust                      291
# R Wildlife Farm and Fields LLC    266
# J&W                               207
# DQ-80                             152
# Name: SurveyID, dtype: int64
# 5:54     70
# 5:52     55
# 7:00     54
# 6:07     53
# 5:28     53
# 7:31     50
# 6:57     42
# 6:51     36
# 8:09     36
# 5:56     35
# 5:40     33
# 5:48     33
# 7:18     33
# 5:41     31
# 7:30     31
# 6:24     30
# 7:08     29
# 6:21     29
# 6:06     27
# 8:37     25
# 8:28     25
# 6:09     25
# 7:14     24
# 7:20     24
# 6:12     24
# 7:19     24
# 6:11     24
# 6:37     23
# 6:30     23
# 7:29     23
# 7:40     23
# 8:08     23
# 6:44     23
# 6:20     23
# 7:43     22
# 6:33     22
# 6:01     22
# 7:06     22
# 7:46     22
# 6:54     21
# 7:05     21
# 8:11     21
# 6:22     20
# 6:47     20
# 7:55     20
# 6:32     19
# 8:23     19
# 7:45     19
# 6:26     19
# 8:00     19
# 6:41     19
# 8:07     18
# 7:28     17
# 00:00    14
# Name: StartTime, dtype: int64
# 5     157
# 1     143
# 6     130
# 4     130
# 2     130
# 3     124
# 9      98
# 7      92
# 8      91
# 20     55
# 10     43
# 11     39
# 19     36
# 17     33
# 22     29
# 21     25
# 16     24
# 15     22
# 23     22
# 18     21
# 13     21
# 12     18
# 14     15
# 88     14
# Name: Point, dtype: int64
# 1.0     581
# 2.0     254
# 3.0     226
# 4.0     171
# 5.0     138
# 6.0     128
# 88.0     14
# Name: Minute, dtype: int64
# DICK    292
# RWBL    261
# BHCO     84
# EAME     74
# COGR     63
#        ...
# WBNU      1
# EAPH      1
# ALFL      1
# YBFL      1
# DOWO      1
# Name: SpeciesCode, Length: 85, dtype: int64
# Dickcissel                       292
# Red-winged Blackbird             261
# Brown-headed Cowbird              84
# Eastern Meadowlark                74
# Common Grackle                    63
#                                 ...
# Cooper's Hawk                      1
# Northern Rough-winged Swallow      1
# American Coot                      1
# Downy Woodpecker                   1
# Upland Sandpiper                   1
# Name: Species, Length: 79, dtype: int64
# 100.0     346
# 150.0     175
# 125.0     139
# 75.0       85
# 50.0       84
# 80.0       70
# 200.0      65
# 120.0      56
# 300.0      52
# 130.0      44
# 60.0       38
# 250.0      38
# 90.0       35
# 175.0      31
# 140.0      30
# 110.0      29
# 30.0       21
# 70.0       20
# 40.0       20
# 133.0      20
# 170.0      18
# 400.0      15
# 225.0      10
# 350.0       9
# 180.0       8
# 500.0       5
# 275.0       5
# 160.0       4
# 20.0        4
# 45.0        4
# 700.0       3
# 220.0       3
# 95.0        3
# 999.0       2
# 65.0        2
# 25.0        2
# 800.0       2
# 600.0       1
# 1000.0      1
# 55.0        1
# 35.0        1
# 240.0       1
# 280.0       1
# 85.0        1
# 115.0       1
# 550.0       1
# 230.0       1
# 10.0        1
# 210.0       1
# 260.0       1
# 190.0       1
# 450.0       1
# Name: Distance, dtype: int64
# Visual    704
# Song      461
# Call      347
# Name: How, dtype: int64
# 0    796
# 1    716
# Name: Visual, dtype: int64
# Unknown     1176
# Male         262
# Female        73
# Juvenile       1
# Name: Sex, dtype: int64
# 0    1509
# 1       3
# Name: Migrating, dtype: int64
# 1.0     1300
# 2.0      114
# 3.0       56
# 4.0       21
# 5.0        6
# 6.0        5
# 20.0       2
# 40.0       1
# 26.0       1
# 43.0       1
# 8.0        1
# 10.0       1
# 28.0       1
# 25.0       1
# 12.0       1
# Name: ClusterSize, dtype: int64
# A    12
# C    10
# D    10
# B    10
# F     8
# E     4
# G     2
# H     2
# J     2
# I     2
# Name: ClusterCode, dtype: int64
# Series([], Name: Notes, dtype: int64)
# Dickcissel               292
# Red-winged               261
# American                 122
# Eastern                  104
# Common                    90
#                         ...
# Northern Rough-winged      1
# Downy                      1
# Tree                       1
# Green                      1
# Upland                     1
# Name: SpeciesName, Length: 62, dtype: int64
# None             330
# Blackbird        261
# Sparrow          153
# Cowbird           84
# Meadowlark        74
# Grackle           63
# Robin             52
# Goldfinch         43
# Dove              37
# Swallow           33
# Yellowthroat      27
# Pheasant          27
# Starling          27
# Bunting           27
# Crow              25
# Cardinal          21
# Kingbird          20
# Error             19
# Oriole            17
# Wren              16
# Thrasher          10
# Vireo             10
# Flycatcher        10
# Swift              9
# Waxwing            9
# Lark               8
# Heron              8
# Goose              8
# Jay                7
# Flicker            6
# Vulture            6
# Woodpecker         6
# Grosbeak           5
# Wood-Pewee         5
# Turkey             5
# Martin             5
# Catbird            4
# Finch              4
# Bluebird           3
# Hawk               3
# Cuckoo             3
# Pigeon             3
# Duck               2
# Titmouse           2
# Thrush             2
# Hummingbird        2
# Gnatcatcher        2
# Sandpiper          1
# Kestrel            1
# Mockingbird        1
# Warbler            1
# Coot               1
# Nuthatch           1
# Collared-Dove      1
# Phoebe             1
# Towhee             1
# Name: SpeciesGroup, dtype: int64

# %%
#### CLEAN (2) ####

# fix 'Error' (Species)
birds.loc[birds['Species']=='Error'] # CLIS, CHIP, TRSW, CAWR, MAGW, AMRC, AMR
# Out:
#                 ObserverID    Year  Month   Day  \
# 64    Colin Kenneth Dobson  2020.0    5.0  27.0
# 65    Colin Kenneth Dobson  2020.0    5.0  27.0
# 66    Colin Kenneth Dobson  2020.0    5.0  27.0
# 67    Colin Kenneth Dobson  2020.0    5.0  27.0
# 113   Colin Kenneth Dobson  2020.0    5.0  27.0
# 178   Colin Kenneth Dobson  2020.0    5.0  27.0
# 477   Colin Kenneth Dobson  2020.0    5.0  29.0
# 700   Colin Kenneth Dobson  2020.0    6.0   1.0
# 797   Colin Kenneth Dobson  2020.0    6.0   1.0
# 856   Colin Kenneth Dobson  2020.0    6.0   1.0
# 1239  Colin Kenneth Dobson  2020.0    6.0   3.0
# 1280  Colin Kenneth Dobson  2020.0    6.0   3.0
# 1391  Colin Kenneth Dobson  2020.0    6.0   3.0
#
#                             SurveyID StartTime Point  Minute SpeciesCode  \
# 64                               J&W      6:37     3     3.0        CLIS
# 65                               J&W      6:37     3     3.0        CLIS
# 66                               J&W      6:37     3     4.0        CLIS
# 67                               J&W      6:37     3     4.0        CLIS
# 113                              J&W      7:14     5     5.0        CHIP
# 178                              J&W      8:28     8     5.0        CLIS
# 477   R Wildlife Farm and Fields LLC      5:28     5     2.0        TRSW
# 700                     Craver Trust      6:12     3     5.0        CAWR
# 797                     Craver Trust      7:08     6     3.0        MAGW
# 856                     Craver Trust      7:40     8     6.0        CAWR
# 1239                  Cow Creek Farm      8:09    14     3.0        AMRC
# 1280                  Cow Creek Farm      7:31    16     2.0         AMR
# 1391                  Cow Creek Farm      5:52    20     1.0         AMR
#
#      Species  Distance     How  Visual      Sex  Migrating  ClusterSize  \
# 64     Error      75.0  Visual       1  Unknown          0          1.0
# 65     Error      75.0  Visual       1  Unknown          0          1.0
# 66     Error      40.0  Visual       1  Unknown          0          1.0
# 67     Error     100.0  Visual       1  Unknown          0          1.0
# 113    Error     400.0    Call       0  Unknown          0          1.0
# 178    Error      75.0  Visual       1  Unknown          0          1.0
# 477    Error      50.0  Visual       1  Unknown          0          1.0
# 700    Error     350.0    Song       0  Unknown          0          1.0
# 797    Error     110.0    Song       0  Unknown          0          1.0
# 856    Error     125.0    Song       0  Unknown          0          1.0
# 1239   Error     300.0    Call       0  Unknown          0          1.0
# 1280   Error     150.0    Song       0  Unknown          0          1.0
# 1391   Error     150.0  Visual       1  Unknown          0          1.0
#
#      ClusterCode  Notes SpeciesName SpeciesGroup
# 64           NaN    NaN       Error        Error
# 65           NaN    NaN       Error        Error
# 66           NaN    NaN       Error        Error
# 67           NaN    NaN       Error        Error
# 113          NaN    NaN       Error        Error
# 178          NaN    NaN       Error        Error
# 477          NaN    NaN       Error        Error
# 700          NaN    NaN       Error        Error
# 797          NaN    NaN       Error        Error
# 856          NaN    NaN       Error        Error
# 1239         NaN    NaN       Error        Error
# 1280         NaN    NaN       Error        Error
# 1391         NaN    NaN       Error        Error

# %%
# fix 'None' (SpeciesGroup)
birds.loc[birds['SpeciesGroup']=='None'] # multiple
# Out:
#                 ObserverID    Year  Month   Day        SurveyID StartTime  \
# 0     Colin Kenneth Dobson  2020.0    5.0  27.0             J&W      6:06
# 5     Colin Kenneth Dobson  2020.0    5.0  27.0             J&W      6:06
# 6     Colin Kenneth Dobson  2020.0    5.0  27.0             J&W      6:06
# 7     Colin Kenneth Dobson  2020.0    5.0  27.0             J&W      6:06
# 12    Colin Kenneth Dobson  2020.0    5.0  27.0             J&W      6:06
# ...                    ...     ...    ...   ...             ...       ...
# 1491  Colin Kenneth Dobson  2020.0    6.0   3.0  Cow Creek Farm      6:33
# 1492  Colin Kenneth Dobson  2020.0    6.0   3.0  Cow Creek Farm      6:33
# 1493  Colin Kenneth Dobson  2020.0    6.0   3.0  Cow Creek Farm      6:33
# 1494  Colin Kenneth Dobson  2020.0    6.0   3.0  Cow Creek Farm      6:33
# 1507  Colin Kenneth Dobson  2020.0    6.0   3.0  Cow Creek Farm      6:33
#
#      Point  Minute SpeciesCode     Species  Distance     How  Visual      Sex  \
# 0        1     1.0        DICK  Dickcissel      30.0  Visual       1  Unknown
# 5        1     1.0        DICK  Dickcissel     150.0    Song       0  Unknown
# 6        1     1.0        DICK  Dickcissel     100.0    Song       0  Unknown
# 7        1     1.0        DICK  Dickcissel     100.0    Song       0  Unknown
# 12       1     3.0        DICK  Dickcissel     200.0  Visual       1  Unknown
# ...    ...     ...         ...         ...       ...     ...     ...      ...
# 1491    23     1.0        DICK  Dickcissel      80.0  Visual       1  Unknown
# 1492    23     1.0        DICK  Dickcissel     100.0    Song       0  Unknown
# 1493    23     1.0        DICK  Dickcissel     100.0    Song       0  Unknown
# 1494    23     1.0        DICK  Dickcissel     125.0    Song       0  Unknown
# 1507    23     4.0        DICK  Dickcissel     120.0  Visual       1  Unknown
#
#       Migrating  ClusterSize ClusterCode  Notes SpeciesName SpeciesGroup
# 0             0          1.0         NaN    NaN  Dickcissel         None
# 5             0          1.0         NaN    NaN  Dickcissel         None
# 6             0          1.0         NaN    NaN  Dickcissel         None
# 7             0          1.0         NaN    NaN  Dickcissel         None
# 12            0          1.0         NaN    NaN  Dickcissel         None
# ...         ...          ...         ...    ...         ...          ...
# 1491          0          2.0         NaN    NaN  Dickcissel         None
# 1492          0          1.0         NaN    NaN  Dickcissel         None
# 1493          0          1.0         NaN    NaN  Dickcissel         None
# 1494          0          1.0         NaN    NaN  Dickcissel         None
# 1507          0          6.0         NaN    NaN  Dickcissel         None
#
# [330 rows x 20 columns]

# %%
#### FEATURE ENGINEERING ####

# normalize time
minutes = birds['StartTime'].apply(lambda x: str(x).split(':')[1]).astype(int)
hours = birds['StartTime'].apply(lambda x: str(x).split(':')[0]).astype(int)
minutes = minutes.apply(lambda x: round(x/60, 2))
birds['StartTime'] = hours+minutes

# %%
birds.head()
# Out:
#              ObserverID    Year  Month   Day SurveyID  StartTime Point  \
# 0  Colin Kenneth Dobson  2020.0    5.0  27.0      J&W        6.1     1
# 1  Colin Kenneth Dobson  2020.0    5.0  27.0      J&W        6.1     1
# 2  Colin Kenneth Dobson  2020.0    5.0  27.0      J&W        6.1     1
# 3  Colin Kenneth Dobson  2020.0    5.0  27.0      J&W        6.1     1
# 4  Colin Kenneth Dobson  2020.0    5.0  27.0      J&W        6.1     1
#
#    Minute SpeciesCode               Species  Distance     How  Visual  \
# 0     1.0        DICK            Dickcissel      30.0  Visual       1
# 1     1.0        AMCR         American Crow     700.0    Call       0
# 2     1.0        BHCO  Brown-headed Cowbird     175.0  Visual       1
# 3     1.0        AMRO        American Robin      90.0    Song       1
# 4     1.0        AMRO        American Robin     250.0    Call       0
#
#        Sex  Migrating  ClusterSize ClusterCode  Notes   SpeciesName  \
# 0  Unknown          0          1.0         NaN    NaN    Dickcissel
# 1  Unknown          0          1.0         NaN    NaN      American
# 2  Unknown          0          1.0         NaN    NaN  Brown-headed
# 3  Unknown          0          1.0         NaN    NaN      American
# 4  Unknown          0          1.0         NaN    NaN      American
#
#   SpeciesGroup
# 0         None
# 1         Crow
# 2      Cowbird
# 3        Robin
# 4        Robin

# %%
codes2 = codes[['4-LetterCode', 'FirstName', 'SecondName']]
codes2.rename(columns={'4-LetterCode':'Alpha Code', 'FirstName':'First Word', 'SecondName':'Second Word'}, inplace=True)

from IPython.display import display, HTML
display(HTML(codes2.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Alpha Code</th>
#       <th>First Word</th>
#       <th>Second Word</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ABTO</td>
#       <td>Abert's</td>
#       <td>Towhee</td>
#     </tr>
#     <tr>
#       <td>ACFL</td>
#       <td>Acadian</td>
#       <td>Flycatcher</td>
#     </tr>
#     <tr>
#       <td>ACWO</td>
#       <td>Acorn</td>
#       <td>Woodpecker</td>
#     </tr>
#     <tr>
#       <td>ADWA</td>
#       <td>Adelaide's</td>
#       <td>Warbler</td>
#     </tr>
#     <tr>
#       <td>AFCD</td>
#       <td>African</td>
#       <td>Collared-Dove</td>
#     </tr>
#     <tr>
#       <td>AFSI</td>
#       <td>African</td>
#       <td>Silverbill</td>
#     </tr>
#     <tr>
#       <td>AGHE</td>
#       <td>Agami</td>
#       <td>Heron</td>
#     </tr>
#     <tr>
#       <td>AISP</td>
#       <td>Ainley's</td>
#       <td>Storm-Petrel</td>
#     </tr>
#     <tr>
#       <td>AKEK</td>
#       <td>Akekee</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <td>AKIA</td>
#       <td>Akiapolaau</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <td>AKIK</td>
#       <td>Akikiki</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <td>AKOH</td>
#       <td>Akohekohe</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <td>ALFL</td>
#       <td>Alder</td>
#       <td>Flycatcher</td>
#     </tr>
#     <tr>
#       <td>ALTE</td>
#       <td>Aleutian</td>
#       <td>Tern</td>
#     </tr>
#     <tr>
#       <td>ALHU</td>
#       <td>Allen's</td>
#       <td>Hummingbird</td>
#     </tr>
#     <tr>
#       <td>ALSW</td>
#       <td>Alpine</td>
#       <td>Swift</td>
#     </tr>
#     <tr>
#       <td>ALOR</td>
#       <td>Altamira</td>
#       <td>Oriole</td>
#     </tr>
#     <tr>
#       <td>ALYE</td>
#       <td>Altamira</td>
#       <td>Yellowthroat</td>
#     </tr>
#     <tr>
#       <td>AMAU</td>
#       <td>Amaui</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <td>AMKI</td>
#       <td>Amazon</td>
#       <td>Kingfisher</td>
#     </tr>
#     <tr>
#       <td>AMAV</td>
#       <td>American</td>
#       <td>Avocet</td>
#     </tr>
#     <tr>
#       <td>AMBI</td>
#       <td>American</td>
#       <td>Bittern</td>
#     </tr>
#     <tr>
#       <td>ABDU</td>
#       <td>American Black</td>
#       <td>Duck</td>
#     </tr>
#     <tr>
#       <td>AMCO</td>
#       <td>American</td>
#       <td>Coot</td>
#     </tr>
#     <tr>
#       <td>AMCR</td>
#       <td>American</td>
#       <td>Crow</td>
#     </tr>
#     <tr>
#       <td>AMDI</td>
#       <td>American</td>
#       <td>Dipper</td>
#     </tr>
#     <tr>
#       <td>AMFL</td>
#       <td>American</td>
#       <td>Flamingo</td>
#     </tr>
#     <tr>
#       <td>AMGP</td>
#       <td>American</td>
#       <td>Golden-Plover</td>
#     </tr>
#     <tr>
#       <td>AMGO</td>
#       <td>American</td>
#       <td>Goldfinch</td>
#     </tr>
#     <tr>
#       <td>AMKE</td>
#       <td>American</td>
#       <td>Kestrel</td>
#     </tr>
#     <tr>
#       <td>AMOY</td>
#       <td>American</td>
#       <td>Oystercatcher</td>
#     </tr>
#     <tr>
#       <td>AMPI</td>
#       <td>American</td>
#       <td>Pipit</td>
#     </tr>
#     <tr>
#       <td>APKI</td>
#       <td>American Pygmy</td>
#       <td>Kingfisher</td>
#     </tr>
#     <tr>
#       <td>AMRE</td>
#       <td>American</td>
#       <td>Redstart</td>
#     </tr>
#     <tr>
#       <td>AMRO</td>
#       <td>American</td>
#       <td>Robin</td>
#     </tr>
#     <tr>
#       <td>ATTW</td>
#       <td>American Three-toed</td>
#       <td>Woodpecker</td>
#     </tr>
#     <tr>
#       <td>ATSP</td>
#       <td>American Tree</td>
#       <td>Sparrow</td>
#     </tr>
#     <tr>
#       <td>AWPE</td>
#       <td>American White</td>
#       <td>Pelican</td>
#     </tr>
#     <tr>
#       <td>AMWI</td>
#       <td>American</td>
#       <td>Wigeon</td>
#     </tr>
#     <tr>
#       <td>AMWO</td>
#       <td>American</td>
#       <td>Woodcock</td>
#     </tr>
#     <tr>
#       <td>ATMG</td>
#       <td>Amethyst-throated</td>
#       <td>Mountain-gem</td>
#     </tr>
#     <tr>
#       <td>ANMU</td>
#       <td>Ancient</td>
#       <td>Murrelet</td>
#     </tr>
#     <tr>
#       <td>ANHI</td>
#       <td>Anhinga</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <td>ANIA</td>
#       <td>Anianiau</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <td>ANHU</td>
#       <td>Anna's</td>
#       <td>Hummingbird</td>
#     </tr>
#     <tr>
#       <td>ANCH</td>
#       <td>Antillean Crested</td>
#       <td>Hummingbird</td>
#     </tr>
#     <tr>
#       <td>ANEU</td>
#       <td>Antillean</td>
#       <td>Euphonia</td>
#     </tr>
#     <tr>
#       <td>ANMA</td>
#       <td>Antillean</td>
#       <td>Mango</td>
#     </tr>
#     <tr>
#       <td>ANNI</td>
#       <td>Antillean</td>
#       <td>Nighthawk</td>
#     </tr>
#     <tr>
#       <td>ANPS</td>
#       <td>Antillean</td>
#       <td>Palm-Swift</td>
#     </tr>
#     <tr>
#       <td>ANPI</td>
#       <td>Antillean</td>
#       <td>Piculet</td>
#     </tr>
#     <tr>
#       <td>ANSI</td>
#       <td>Antillean</td>
#       <td>Siskin</td>
#     </tr>
#     <tr>
#       <td>APAP</td>
#       <td>Apapane</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <td>APFA</td>
#       <td>Aplomado</td>
#       <td>Falcon</td>
#     </tr>
#     <tr>
#       <td>ARLO</td>
#       <td>Arctic</td>
#       <td>Loon</td>
#     </tr>
#     <tr>
#       <td>ARTE</td>
#       <td>Arctic</td>
#       <td>Tern</td>
#     </tr>
#     <tr>
#       <td>ARWA</td>
#       <td>Arctic</td>
#       <td>Warbler</td>
#     </tr>
#     <tr>
#       <td>ARWO</td>
#       <td>Arizona</td>
#       <td>Woodpecker</td>
#     </tr>
#     <tr>
#       <td>ARRW</td>
#       <td>Arrowhead</td>
#       <td>Warbler</td>
#     </tr>
#     <tr>
#       <td>ATFL</td>
#       <td>Ash-throated</td>
#       <td>Flycatcher</td>
#     </tr>
#     <tr>
#       <td>ASSP</td>
#       <td>Ashy</td>
#       <td>Storm-Petrel</td>
#     </tr>
#     <tr>
#       <td>AFOW</td>
#       <td>Ashy-faced</td>
#       <td>Owl</td>
#     </tr>
#     <tr>
#       <td>ATCH</td>
#       <td>Ashy-throated</td>
#       <td>Chlorospingus</td>
#     </tr>
#     <tr>
#       <td>ABFL</td>
#       <td>Asian Brown</td>
#       <td>Flycatcher</td>
#     </tr>
#     <tr>
#       <td>ASRF</td>
#       <td>Asian</td>
#       <td>Rosy-Finch</td>
#     </tr>
#     <tr>
#       <td>ATGR</td>
#       <td>Atitlan</td>
#       <td>Grebe</td>
#     </tr>
#     <tr>
#       <td>ATPU</td>
#       <td>Atlantic</td>
#       <td>Puffin</td>
#     </tr>
#     <tr>
#       <td>AUOR</td>
#       <td>Audubon's</td>
#       <td>Oriole</td>
#     </tr>
#     <tr>
#       <td>AUSH</td>
#       <td>Audubon's</td>
#       <td>Shearwater</td>
#     </tr>
#     <tr>
#       <td>AZRA</td>
#       <td>Aztec</td>
#       <td>Rail</td>
#     </tr>
#     <tr>
#       <td>AZTH</td>
#       <td>Aztec</td>
#       <td>Thrush</td>
#     </tr>
#     <tr>
#       <td>AZGA</td>
#       <td>Azure</td>
#       <td>Gallinule</td>
#     </tr>
#     <tr>
#       <td>AZCH</td>
#       <td>Azure-crowned</td>
#       <td>Hummingbird</td>
#     </tr>
#     <tr>
#       <td>AHJA</td>
#       <td>Azure-hooded</td>
#       <td>Jay</td>
#     </tr>
#     <tr>
#       <td>ARTA</td>
#       <td>Azure-rumped</td>
#       <td>Tanager</td>
#     </tr>
#     <tr>
#       <td>BACS</td>
#       <td>Bachman's</td>
#       <td>Sparrow</td>
#     </tr>
#     <tr>
#       <td>BAWA</td>
#       <td>Bachman's</td>
#       <td>Warbler</td>
#     </tr>
#     <tr>
#       <td>BAMO</td>
#       <td>Bahama</td>
#       <td>Mockingbird</td>
#     </tr>
#     <tr>
#       <td>BAHO</td>
#       <td>Bahama</td>
#       <td>Oriole</td>
#     </tr>
#     <tr>
#       <td>BAHS</td>
#       <td>Bahama</td>
#       <td>Swallow</td>
#     </tr>
#     <tr>
#       <td>BAHW</td>
#       <td>Bahama</td>
#       <td>Warbler</td>
#     </tr>
#     <tr>
#       <td>BAWO</td>
#       <td>Bahama</td>
#       <td>Woodstar</td>
#     </tr>
#     <tr>
#       <td>BAYE</td>
#       <td>Bahama</td>
#       <td>Yellowthroat</td>
#     </tr>
#     <tr>
#       <td>BATE</td>
#       <td>Baikal</td>
#       <td>Teal</td>
#     </tr>
#     <tr>
#       <td>BAJU</td>
#       <td>Baird's</td>
#       <td>Junco</td>
#     </tr>
#     <tr>
#       <td>BASA</td>
#       <td>Baird's</td>
#       <td>Sandpiper</td>
#     </tr>
#     <tr>
#       <td>BAIS</td>
#       <td>Baird's</td>
#       <td>Sparrow</td>
#     </tr>
#     <tr>
#       <td>BATR</td>
#       <td>Baird's</td>
#       <td>Trogon</td>
#     </tr>
#     <tr>
#       <td>BAEA</td>
#       <td>Bald</td>
#       <td>Eagle</td>
#     </tr>
#     <tr>
#       <td>BASO</td>
#       <td>Balsas</td>
#       <td>Screech-Owl</td>
#     </tr>
#     <tr>
